# %%
# %matplotlib inline
import data_utils
import canny_edge_detector as ced

DIR_NAME = '../Teeth/'
IMG_TEST_LIST = [DIR_NAME+"1435_017906.jpg", DIR_NAME+"1435_020558.jpg", DIR_NAME+"1435_022940.jpg"]
IMG_TEMPLATES = ['templates/frontal.jpg', 'templates/left.jpg', 'templates/lower.jpg', 'templates/right_big.jpg']
IMGE_TEMPLATES_TITLES = ['frontal', 'left', 'lower', 'right_big']

# %%
tmp_color_imgs, tmp_gray_imgs = data_utils.load_data(dir_name=None, img_list=IMG_TEMPLATES)

data_utils.visualize_image(tmp_gray_imgs, IMGE_TEMPLATES_TITLES, gray=True)
